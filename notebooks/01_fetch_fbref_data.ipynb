# %%
from pathlib import Path
import sys

project_root = Path.cwd().resolve().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))
from src.data_fetch import fetch_fbref_data

fetch_fbref_data()
# Out:
# [11/19/25 21:29:18] INFO     No custom team name replacements found. You can configure these in       ]8;id=559065;file:///opt/anaconda3/lib/python3.12/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=254899;file:///opt/anaconda3/lib/python3.12/site-packages/soccerdata/_config.py#91\91]8;;\
#                              /Users/r.berkkaratas/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=949379;file:///opt/anaconda3/lib/python3.12/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=505117;file:///opt/anaconda3/lib/python3.12/site-packages/soccerdata/_config.py#197\197]8;;\
#                              /Users/r.berkkaratas/soccerdata/config/league_dict.json.
# ...
